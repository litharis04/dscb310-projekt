# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
from IPython.display import display

# %%
# Daten laden
df_clickstreams = pd.read_parquet('data/clickstreams.parquet')

rows_initial = len(df_clickstreams)
print(f"Anzahl der Zeilen: {rows_initial}")
print(f"Anzahl der Spalten: {len(df_clickstreams.columns)}")
print(f"\nSpalten: {list(df_clickstreams.columns)}")
# Out:
# Anzahl der Zeilen: 10567737
# Anzahl der Spalten: 6
#
# Spalten: ['session_user_id', 'session_action', 'session_action_type', 'session_action_detail', 'session_device_type', 'time_passed_in_seconds']

# %%
df_clickstreams.head(25)
# Out:
#    session_user_id         session_action session_action_type  \
# 0       d1mm9tcy42                 lookup                None
# 1       d1mm9tcy42         search_results               click
# 2       d1mm9tcy42                 lookup                None
# 3       d1mm9tcy42         search_results               click
# 4       d1mm9tcy42                 lookup                None
# 5       d1mm9tcy42         search_results               click
# 6       d1mm9tcy42                 lookup                None
# 7       d1mm9tcy42            personalize                data
# 8       d1mm9tcy42                  index                view
# 9       d1mm9tcy42                 lookup                None
# 10      d1mm9tcy42         search_results               click
# 11      d1mm9tcy42                 lookup                None
# 12      d1mm9tcy42            personalize                data
# 13      d1mm9tcy42                  index                view
# 14      d1mm9tcy42       similar_listings                data
# 15      d1mm9tcy42  ajax_refresh_subtotal               click
# 16      d1mm9tcy42       similar_listings                data
# 17      d1mm9tcy42  ajax_refresh_subtotal               click
# 18      d1mm9tcy42                   show                None
# 19      d1mm9tcy42            personalize                data
# 20      d1mm9tcy42                   show                view
# 21      d1mm9tcy42                 lookup                None
# 22      d1mm9tcy42         search_results               click
# 23      d1mm9tcy42                 lookup                None
# 24      d1mm9tcy42         search_results               click
#
#           session_action_detail session_device_type  time_passed_in_seconds
# 0                          None     Windows Desktop                   319.0
# 1           view_search_results     Windows Desktop                 67753.0
# 2                          None     Windows Desktop                   301.0
# 3           view_search_results     Windows Desktop                 22141.0
# 4                          None     Windows Desktop                   435.0
# 5           view_search_results     Windows Desktop                  7703.0
# 6                          None     Windows Desktop                   115.0
# 7       wishlist_content_update     Windows Desktop                   831.0
# 8           view_search_results     Windows Desktop                 20842.0
# 9                          None     Windows Desktop                   683.0
# 10          view_search_results     Windows Desktop                 59274.0
# 11                         None     Windows Desktop                    95.0
# 12      wishlist_content_update     Windows Desktop                  1399.0
# 13          view_search_results     Windows Desktop                 74886.0
# 14             similar_listings     Windows Desktop                   255.0
# 15  change_trip_characteristics     Windows Desktop                  8134.0
# 16             similar_listings     Windows Desktop                   183.0
# 17  change_trip_characteristics     Windows Desktop                175570.0
# 18                         None     Windows Desktop                    86.0
# 19      wishlist_content_update     Windows Desktop                  1535.0
# 20                           p3     Windows Desktop                 83251.0
# 21                         None     Windows Desktop                   360.0
# 22          view_search_results     Windows Desktop                  2488.0
# 23                         None     Windows Desktop                   456.0
# 24          view_search_results     Windows Desktop                 10053.0

# %%
df_clickstreams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   session_user_id         object
#  1   session_action          object
#  2   session_action_type     object
#  3   session_action_detail   object
#  4   session_device_type     object
#  5   time_passed_in_seconds  float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %%
df_clickstreams.session_user_id.nunique()
# Out:
# 135483

# %%
text_cols = ['session_action', 'session_action_type', 'session_action_detail', 'session_device_type']
for col in text_cols:
    print(df_clickstreams[col].value_counts(dropna=False))
    print('-' * 80)
# Out:
# session_action
# show              2768278
# index              843699
# search_results     725226
# personalize        706824
# search             536057
#                    ...
# deauthorize             1
# events                  1
# reactivate              1
# desks                   1
# nyan                    1
# Name: count, Length: 360, dtype: int64
# --------------------------------------------------------------------------------
# session_action_type
# view                3560902
# data                2103770
# click               1996183
# None                1126204
# -unknown-           1031170
# submit               623357
# message_post          87103
# partner_callback      19132
# booking_request       18773
# modify                 1139
# booking_response          4
# Name: count, dtype: int64
# --------------------------------------------------------------------------------
# session_action_detail
# view_search_results         1776885
# p3                          1376550
# None                        1126204
# -unknown-                   1031141
# wishlist_content_update      706824
#                              ...
# special_offer_field               3
# tos_2014                          2
# host_refund_guest                 2
# host_respond_page                 2
# host_standard_suspension          1
# Name: count, Length: 156, dtype: int64
# --------------------------------------------------------------------------------
# session_device_type
# Mac Desktop                         3594286
# Windows Desktop                     2658539
# iPhone                              2105031
# Android Phone                        839637
# iPad Tablet                          683414
# Android App Unknown Phone/Tablet     273652
# -unknown-                            211279
# Tablet                               139886
# Linux Desktop                         28373
# Chromebook                            22348
# iPodtouch                              8198
# Windows Phone                          2047
# Blackberry                              979
# Opera Phone                              68
# Name: count, dtype: int64
# --------------------------------------------------------------------------------
